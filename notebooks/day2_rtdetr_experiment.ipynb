# %%
from google.colab import drive
drive.mount('/content/drive')

BASE = '/content/drive/MyDrive/pill_detection'
DATA_DIR = f'{BASE}/data'
TRAIN_IMG_DIR = f'{DATA_DIR}/train_images'
TRAIN_ANN_DIR = f'{DATA_DIR}/train_annotations'
TEST_IMG_DIR = f'{DATA_DIR}/test_images'
OUTPUT_DIR = f'{BASE}/outputs'
YOLO_DIR = f'{BASE}/yolo_data'
yaml_path = f'{YOLO_DIR}/data.yaml'

import os
os.makedirs(OUTPUT_DIR, exist_ok=True)

# !pip install ultralytics ensemble-boxes -q
# Out:
# Mounted at /content/drive
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.0 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')

BASE = '/content/drive/MyDrive/pill_detection'
DATA_DIR = f'{BASE}/data'
TRAIN_IMG_DIR = f'{DATA_DIR}/train_images'
TRAIN_ANN_DIR = f'{DATA_DIR}/train_annotations'
TEST_IMG_DIR = f'{DATA_DIR}/test_images'
OUTPUT_DIR = f'{BASE}/outputs'
YOLO_DIR = f'{BASE}/yolo_data'
yaml_path = f'{YOLO_DIR}/data.yaml'

import os
os.makedirs(OUTPUT_DIR, exist_ok=True)

# !pip install ultralytics -q
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import RTDETR

model = RTDETR('rtdetr-l.pt')

results = model.train(
    data=yaml_path,
    epochs=50,
    imgsz=1024,      # RAM 절약용 640으로 시작
    batch=2,        # 어제 터진 원인, 2로 고정
    project=f'{BASE}/runs',
    name='rtdetr_exp',
    optimizer='AdamW',
    lr0=0.0001,
    warmup_epochs=3,
    cos_lr=True,
    patience=20,
    save=True,
    device=0
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/rtdetr-l.pt to 'rtdetr-l.pt': 100% ━━━━━━━━━━━━ 63.4MB 243.2MB/s 0.3s
# Ultralytics 8.4.45 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=2, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/drive/MyDrive/pill_detection/yolo_data/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=rtdetr-l.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=rtdetr_exp-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/pill_detection/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/pill_detection/runs/rtdetr_exp-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.Unicode.ttf to '/root/.config/Ultralytics/Arial.Unicode.ttf': 100% ━━━━━━━━━━━━ 22.2MB 189.1MB/s 0.1s
# Overriding model.yaml nc=80 with nc=56
# WARNING ⚠️ no model scale passed. Assuming scale='l'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1     25248  ultralytics.nn.modules.block.HGStem          [3, 32, 48]
#   1                  -1  6    155072  ultralytics.nn.modules.block.HGBlock         [48, 48, 128, 3, 6]
#   2                  -1  1      1408  ultralytics.nn.modules.conv.DWConv           [128, 128, 3, 2, 1, False]
#   3                  -1  6    839296  ultralytics.nn.modules.block.HGBlock         [128, 96, 512, 3, 6]
#   4                  -1  1      5632  ultralytics.nn.modules.conv.DWConv           [512, 512, 3, 2, 1, False]
#   5                  -1  6   1695360  ultralytics.nn.modules.block.HGBlock         [512, 192, 1024, 5, 6, True, False]
#   6                  -1  6   2055808  ultralytics.nn.modules.block.HGBlock         [1024, 192, 1024, 5, 6, True, True]
#   7                  -1  6   2055808  ultralytics.nn.modules.block.HGBlock         [1024, 192, 1024, 5, 6, True, True]
#   8                  -1  1     11264  ultralytics.nn.modules.conv.DWConv           [1024, 1024, 3, 2, 1, False]
#   9                  -1  6   6708480  ultralytics.nn.modules.block.HGBlock         [1024, 384, 2048, 5, 6, True, False]
#  10                  -1  1    524800  ultralytics.nn.modules.conv.Conv             [2048, 256, 1, 1, None, 1, 1, False]
#  11                  -1  1    789760  ultralytics.nn.modules.transformer.AIFI      [256, 1024, 8]
#  12                  -1  1     66048  ultralytics.nn.modules.conv.Conv             [256, 256, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14                   7  1    262656  ultralytics.nn.modules.conv.Conv             [1024, 256, 1, 1, None, 1, 1, False]
#  15            [-2, -1]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  17                  -1  1     66048  ultralytics.nn.modules.conv.Conv             [256, 256, 1, 1]
#  18                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  19                   3  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1, None, 1, 1, False]
#  20            [-2, -1]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  22                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  23            [-1, 17]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  24                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  25                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  26            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  27                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  28        [21, 24, 27]  1   7416932  ultralytics.nn.modules.head.RTDETRDecoder    [56, [256, 256, 256]]
# rt-detr-l summary: 465 layers, 32,921,156 parameters, 32,921,156 gradients, 108.2 GFLOPs
#
# Transferred 926/941 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 69.9MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.7±0.1 ms, read: 74.7±156.1 MB/s, size: 1705.3 KB)
# train: Scanning /content/drive/MyDrive/pill_detection/yolo_data/labels/train.cache... 232 images, 0 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 232/232 38.9Mit/s 0.0s
# train: /content/drive/MyDrive/pill_detection/yolo_data/images/train/K-003351-016262-018357_0_2_0_2_75_000_200.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     6.8878]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 1.3±1.0 ms, read: 148.1±35.8 MB/s, size: 1701.5 KB)
# val: Scanning /content/drive/MyDrive/pill_detection/yolo_data/labels/train.cache... 232 images, 0 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 232/232 1.1Mit/s 0.0s
# train: /content/drive/MyDrive/pill_detection/yolo_data/images/train/K-003351-016262-018357_0_2_0_2_75_000_200.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     6.8878]
# optimizer: AdamW(lr=0.0001, momentum=0.937) with parameter groups 143 weight(decay=0.0), 206 weight(decay=0.0005), 226 bias(decay=0.0)
# Plotting labels to /content/drive/MyDrive/pill_detection/runs/rtdetr_exp-2/labels.jpg...
# Image sizes 1024 train, 1024 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/pill_detection/runs/rtdetr_exp-2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        1/50       3.7G      1.109      1.214     0.7136         16       1024: 0% ──────────── 0/116  6.7s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.2MB/s 0.0s
#        1/50      3.85G      1.624     0.7007      1.633          9       1024: 100% ━━━━━━━━━━━━ 116/116 1.7it/s 1:10
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 3.0it/s 19.2s
#                    all        231        760   2.88e-06    0.00531   1.03e-05   1.79e-06
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        2/50       4.1G      1.432     0.8599     0.9004          9       1024: 0% ──────────── 0/116  0.5s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        2/50       4.1G      1.193      0.957     0.7671          9       1024: 100% ━━━━━━━━━━━━ 116/116 2.0it/s 59.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 4
1024: 0% ──────────── 0/116  0.5s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       36/50       4.1G     0.1993      2.497     0.1041          2       1024: 100% ━━━━━━━━━━━━ 116/116 1.6it/s 1:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 4.0it/s 14.4s
#                    all        231        760     0.0228      0.112     0.0144      0.012
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       37/50       4.1G     0.2159      2.445    0.07802         15       1024: 0% ──────────── 0/116  0.6s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       37/50       4.1G     0.1945      2.447     0.1011         10       1024: 100% ━━━━━━━━━━━━ 116/116 1.6it/s 1:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 3.9it/s 14.7s
#                    all        231        760     0.0405      0.119     0.0148     0.0126
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       38/50       4.1G      0.217      2.307    0.08334         13       1024: 0% ──────────── 0/116  0.5s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       38/50       4.1G     0.1936      2.515     0.1024          6       1024: 100% ━━━━━━━━━━━━ 116/116 1.7it/s 1:10
# ...
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       41/50       4.1G     0.1519       2.72    0.08967          3       1024: 100% ━━━━━━━━━━━━ 116/116 1.6it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 3.9it/s 14.8s
#                    all        231        760     0.0614      0.155     0.0242     0.0199
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       42/50       4.1G     0.1673      2.795    0.07031          8       1024: 0% ──────────── 0/116  0.5s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       42/50       4.1G     0.1437      2.699    0.08905          3       1024: 100% ━━━━━━━━━━━━ 116/116 1.6it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 3.9it/s 15.0s
#                    all        231        760     0.0483      0.161     0.0224      0.018
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       43/50       4.1G     0.1344      2.489    0.09819          6       1024: 0% ──────────── 0/116  0.5s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       43/50       4.1G     0.1429      2.698    0.08479          4       1024: 100% ━━━━━━━━━━━━ 116/116 1.8it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 4.0it/s 14.6s
#                    all        231        760     0.0402      0.171     0.0207     0.0178
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       44/50       4.1G      0.125      2.553    0.07186          6       1024: 0% ──────────── 0/116  0.5s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       44/50       4.1G     0.1463      2.684    0.08764          4       1024: 100% ━━━━━━━━━━━━ 116/116 1.8it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 4.0it/s 14.6s
#                    all        231        760     0.0642      0.165     0.0242     0.0192
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       45/50       4.1G     0.1205      2.573    0.08734          6       1024: 0% ──────────── 0/116  0.6s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       45/50       4.1G     0.1455      2.675     0.0851          4       1024: 100% ━━━━━━━━━━━━ 116/116 1.8it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 4.0it/s 14.6s
#                    all        231        760     0.0406      0.174     0.0206     0.0174
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       46/50       4.1G     0.1374      2.478    0.07262          6       1024: 0% ──────────── 0/116  0.5s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       46/50       4.1G     0.1405      2.673    0.08515          3       1024: 100% ━━━━━━━━━━━━ 116/116 1.8it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 3.9it/s 14.8s
#                    all        231        760     0.0577      0.174     0.0223     0.0181
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       47/50       4.1G      0.133      2.392    0.07111          6       1024: 0% ──────────── 0/116  0.5s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       47/50       4.1G     0.1425      2.665     0.0797          4       1024: 100% ━━━━━━━━━━━━ 116/116 1.8it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 4.0it/s 14.3s
#                    all        231        760      0.082      0.177     0.0186     0.0158
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       48/50       4.1G     0.1268      2.459    0.08004          6       1024: 0% ──────────── 0/116  0.5s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       48/50       4.1G     0.1457      2.656    0.08555          3       1024: 100% ━━━━━━━━━━━━ 116/116 1.8it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 3.9it/s 15.0s
#                    all        231        760      0.063      0.181     0.0227     0.0188
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       49/50       4.1G      0.158      2.773     0.1124          7       1024: 0% ──────────── 0/116  0.5s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       49/50       4.1G     0.1455      2.665    0.08432          3       1024: 100% ━━━━━━━━━━━━ 116/116 1.8it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 3.9it/s 14.9s
#                    all        231        760    0.00559      0.179     0.0211     0.0177
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#       50/50       4.1G     0.1521      2.519    0.06176          6       1024: 0% ──────────── 0/116  0.5s
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:160.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       50/50       4.1G     0.1477      2.655    0.08295          4       1024: 100% ━━━━━━━━━━━━ 116/116 1.8it/s 1:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 3.9it/s 14.7s
#                    all        231        760     0.0632      0.179     0.0221     0.0177
#
# 50 epochs completed in 1.163 hours.
# Optimizer stripped from /content/drive/MyDrive/pill_detection/runs/rtdetr_exp-2/weights/last.pt, 66.6MB
# Optimizer stripped from /content/drive/MyDrive/pill_detection/runs/rtdetr_exp-2/weights/best.pt, 66.6MB
#
# Validating /content/drive/MyDrive/pill_detection/runs/rtdetr_exp-2/weights/best.pt...
# Ultralytics 8.4.45 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# rt-detr-l summary: 310 layers, 32,098,820 parameters, 0 gradients, 103.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 58/58 3.4it/s 16.8s
#                    all        231        760     0.0436      0.156     0.0244       0.02
#             보령부스파정 5mg         15         15          0          0          0          0
#            뮤테란캡슐 100mg          9          9          0          0          0          0
#            일양하이트린정 2mg        152        152    0.00749      0.993      0.152      0.107
#     기넥신에프정(은행엽엑스)(수출용)         45         45    0.00708          1     0.0907      0.072
#      무코스타정(레바미피드)(비매품)          6          6          0          0          0          0
#                   알드린정          3          3          0          0          0          0
#           뉴로메드정(옥시라세탐)         20         20     0.0161       0.65     0.0667     0.0416
#           에어탈정(아세클로페낙)          5          5          0          0          0          0
#        리렉스펜정 300mg/PTP          3          3          0          0          0          0
#            아빌리파이정 10mg          3          3          0          0          0          0
#          다보타민큐정 10mg/병          6          6          0          0          0          0
#      써스펜8시간이알서방정 650mg          3          3          0          0          0          0
#      에빅사정(메만틴염산염)(비매품)         15         15     0.0204      0.267     0.0702     0.0634
#              리피토정 20mg         21         21     0.0173     0.0476      0.045     0.0405
#             크레스토정 20mg         22         22     0.0154      0.227    0.00361    0.00207
#            가바토파정 100mg         18         18      0.175     0.0556     0.0138     0.0055
#          동아가바펜틴정 800mg          3          3          0          0          0          0
# 오마코연질캡슐(오메가-3-산에틸에스테르90)          8          8          1          0          0          0
#            리리카캡슐 150mg         15         15          0          0          0          0
# 종근당글리아티린연질캡슐(콜린알포세레이트)          12         12          0          0          0          0
#        콜리네이트연질캡슐 400mg         17         17     0.0141      0.882     0.0777     0.0682
#           트루비타정 60mg/병          3          3          0          0          0          0
#              스토가정 10mg          6          6          0          0          0          0
#              노바스크정 5mg          6          6          0          0          0          0
#                   마도파정         16         16     0.0194       0.75      0.104      0.086
#             플라빅스정 75mg         20         20     0.0156        0.3    0.00702    0.00503
#          엑스포지정 5/160mg         12         12          0          0          0          0
#             아토르바정 10mg         22         22     0.0146          1      0.178      0.151
#             라비에트정 20mg          3          3          0          0          0          0
#             리피로우정 20mg         16         16     0.0247        0.5      0.139      0.125
#             자누비아정 50mg          9          9          0          0          0          0
#          맥시부펜이알정 300mg          3          3          0          0          0          0
#               놀텍정 10mg          3          3          0          0          0          0
#         자누메트정 50/850mg         12         12          1          0          0          0
#        큐시드정 31.5mg/PTP          6          6          0          0          0          0
#          아모잘탄정 5/100mg         12         12          0          0          0          0
#           트윈스타정 40/5mg         12         12          0          0          0          0
#              카나브정 60mg          3          3          0          0          0          0
#              울트라셋이알서방정          3          3          0          0          0          0
#            졸로푸트정 100mg          3          3          0          0          0          0
#           트라젠타정(리나글립틴)          9          9          0          0          0          0
#          비모보정 500/20mg          6          6          0          0          0          0
#                   레일라정          3          3          0          0          0          0
#               리바로정 4mg         18         18          0          0          0          0
#      트라젠타듀오정 2.5/850mg          9          9          0          0          0          0
#        아질렉트정(라사길린메실산염)         12         12          0          0          0          0
#  자누메트엑스알서방정 100/1000mg          3          3          0          0          0          0
#              글리아타민연질캡슐         14         14          0          0          0          0
#                   신바로정          3          3          0          0          0          0
#            에스원엠프정 20mg          3          3          0          0          0          0
#         글리틴정(콜린알포세레이트)         16         16     0.0155     0.0625      0.065     0.0585
#      제미메트서방정 50/1000mg          3          3          0          0          0          0
#           아토젯정 10/40mg         37         37    0.00261          1      0.103     0.0685
#           로수젯정10/5밀리그램         19         19     0.0215      0.368      0.082     0.0737
#         로수바미브정 10/20mg         18         18     0.0337      0.111      0.061     0.0549
#             카발린캡슐 25mg         16         16     0.0235        0.5      0.107     0.0946
# Speed: 0.9ms preprocess, 54.3ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /content/drive/MyDrive/pill_detection/runs/rtdetr_exp-2

# %%
os.makedirs(f'{BASE}/runs/faster_rcnn', exist_ok=True)
